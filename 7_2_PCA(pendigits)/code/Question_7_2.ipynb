# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('./Data/Q_2.csv')
df_train = pd.read_csv('./Data/Q_2_train.csv')
df_test = pd.read_csv('./Data/Q_2_test.csv')

# %%
df_train
df_test
# Out:
#        V1   V2  V3   V4   V5   V6  V7   V8   V9  V10  ...  V27  V28  V29  V30  \
# 0       0  100   7   92    5   68  19   45   86   34  ...   86   34  100   45
# 1       0   67  49   83  100  100  81   80   60   60  ...   60   60   40   40
# 2       0  100   3   72   26   35  85   35  100   71  ...  100   71   73   97
# 3       0   39   2   62   11    5  63    0  100   43  ...  100   43   89   99
# 4      13   89  12   50   72   38  56    0    4   17  ...    4   17    0   61
# ...   ...  ...  ..  ...  ...  ...  ..  ...  ...  ...  ...  ...  ...  ...  ...
# 3293    1   82  42  100   64   79  42   61   96   49  ...   96   49  100   17
# 3294   11   75   4   45   21    1  81    0  100   43  ...  100   43   88   87
# 3295  100   69  54   61   13   77  56  100   96   77  ...   96   77   90   44
# 3296   36  100  24   70    0   38  49   33   95   47  ...   95   47   87   55
# 3297   19  100   0   61    3   23  48    0   97   27  ...   97   27  100   66
#
# ...

# %%
df = pd.read_csv('./Data/Q_2.csv')

# %%
df.loc[:,'V1':'V35']
# Out:
#        V1   V2  V3   V4   V5   V6   V7   V8  V9  V10  ...  V26  V27  V28  V29  \
# 0      47  100  27   81   57   37   26    0   0   23  ...    0    0   23   56
# 1       0   89  27  100   42   75   29   45  15   15  ...   45   15   15   37
# 2       0   57  31   68   72   90  100  100  76   75  ...  100   76   75   50
# 3       0  100   7   92    5   68   19   45  86   34  ...   45   86   34  100
# 4       0   67  49   83  100  100   81   80  60   60  ...   80   60   60   40
# ...    ..  ...  ..  ...  ...  ...  ...  ...  ..  ...  ...  ...  ...  ...  ...
# 10987  36  100  24   70    0   38   49   33  95   47  ...   33   95   47   87
# 10988  16   75  41  100   52   64   32   27   0    0  ...   27    0    0   21
# 10989  56  100  27   79    0   39   12    0  66   15  ...    0   66   15  100
# 10990  19  100   0   61    3   23   48    0  97   27  ...    0   97   27  100
# 10991  38  100  37   81   12   55    0   28  52   27  ...   28   52   27  100
#
# ...

# %%
sns.heatmap(df.loc[:,'V1':'V35'].corr(),cmap="BrBG")

# %%
x = StandardScaler().fit_transform(df.loc[:,'V1':'V35'])

# %%
x
# Out:
# array([[ 0.23895455,  0.91749192, -0.51650341, ..., -0.17451493,
#          1.93296504,  1.24040384],
#        [-1.13305889,  0.23922621, -0.51650341, ...,  1.26231828,
#         -0.63855782, -0.84523541],
#        [-1.13305889, -1.73391041, -0.36465342, ..., -0.74924822,
#         -0.80626583, -1.19284196],
#        ...,
#        [ 0.50168052,  0.91749192, -0.51650341, ..., -0.22240937,
#          1.79320836, -1.5404485 ],
#        [-0.57841516,  0.91749192, -1.54149087, ..., -0.89293154,
#          1.45779234, -1.5404485 ],
#        [-0.02377143,  0.91749192, -0.13687843, ...,  0.42416557,
#         -0.80626583, -0.15002233]])

# %%
y=df.loc[:,['V36']].values

# %%
y
# Out:
# array([[1],
#        [2],
#        [3],
#        ...,
#        [5],
#        [5],
#        [6]], dtype=int64)

# %%
pca = PCA(n_components = 35)
#principalComponents = pca.fit_transform(x)
pca_fit=pca.fit(df)

# %%
plt.title('Screen Plot')
plt.xlabel('NumOfComponents')
plt.title('CumulativeExplainedVariance')
plt.plot(pca.explained_variance_,'o-')
percent=pca.explained_variance_[0]-pca.explained_variance_/pca.explained_variance_[0]
# Out:
# [8426.52768781 8426.64859284 8426.98510353 8427.20925566 8427.32302761
#  8427.35716665 8427.41897816 8427.43330293 8427.45961197 8427.47904678
#  8427.49703793 8427.50384781 8427.51188349 8427.51375028 8427.52105243
#  8427.52184646 8427.52638513 8427.52680162 8427.52768781 8427.52768781
#  8427.52768781 8427.52768781 8427.52768781 8427.52768781 8427.52768781
#  8427.52768781 8427.52768781 8427.52768781 8427.52768781 8427.52768781
#  8427.52768781 8427.52768781 8427.52768781 8427.52768781 8427.52768781]

# %%
explain=pca.explained_variance_
fst_val=explain[0]
percentage=[]
for ind,ele in enumerate(explain):

    exp=((fst_val-ele)/fst_val)*100
    print(ind,'NumberOfComponents explain ',round(exp),'Percentage For the model')
    percentage.append(exp)


percentage
# Out:
# 0 NumberOfComponents explain  0.0 Percentage For the model
# 1 NumberOfComponents explain  12.0 Percentage For the model
# 2 NumberOfComponents explain  46.0 Percentage For the model
# 3 NumberOfComponents explain  68.0 Percentage For the model
# 4 NumberOfComponents explain  80.0 Percentage For the model
# 5 NumberOfComponents explain  83.0 Percentage For the model
# 6 NumberOfComponents explain  89.0 Percentage For the model
# 7 NumberOfComponents explain  91.0 Percentage For the model
# 8 NumberOfComponents explain  93.0 Percentage For the model
# 9 NumberOfComponents explain  95.0 Percentage For the model
# 10 NumberOfComponents explain  97.0 Percentage For the model
# 11 NumberOfComponents explain  98.0 Percentage For the model
# 12 NumberOfComponents explain  98.0 Percentage For the model
# 13 NumberOfComponents explain  99.0 Percentage For the model
# 14 NumberOfComponents explain  99.0 Percentage For the model
# 15 NumberOfComponents explain  99.0 Percentage For the model
# ...

# %%
pca_3 = PCA(n_components = 3)
#principalComponents = pca.fit_transform(x)
pca_3_fit=pca_3.fit(df)
#ucq=pca_pred['V36'].unique()
pca_pred=pd.DataFrame(pca_3.fit_transform(df))
pca_pred=pd.concat([pca_pred,df['V36']],axis=1)
pca_pred
sns.scatterplot(pca_pred[0],pca_pred[1], 
                data=pca_pred,hue='V36',s=100)

pca_pred
# Out:
#                 0           1           2  V36
# 0      155.572090    5.008589  -29.986496    1
# 1      -13.729006  107.304504  -29.439170    2
# 2     -106.065952  -12.333056  110.232559    3
# 3       -4.196143  -47.767962   11.456619    6
# 4     -100.881164   50.671811   76.434721    3
# ...           ...         ...         ...  ...
# 10987   20.786956  -47.253154   22.159289    6
# 10988   11.008252  129.983316  -45.926692    2
# 10989  154.351702  -87.473667  -38.883297    5
# 10990  141.294297 -124.903371   52.231178    5
# 10991   21.697763  -41.859267  -56.550028    6
#
# [10992 rows x 4 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-135-a311947c4d97> in <module>
# ----> 1 from bioinfokit.visuz import cluster
#
# ModuleNotFoundError: No module named 'bioinfokit'

# %%
# !pip install bioinfokit.visuz
# Out:
# ERROR: Could not find a version that satisfies the requirement bioinfokit.visuz (from versions: none)
# ERROR: No matching distribution found for bioinfokit.visuz

# %%
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.scatter(pca_pred[0],pca_pred[1], pca_pred[2], c=pca_pred['V36'], cmap="Set2_r", s=60)

# %%
df_train = pd.read_csv('./Data/Q_2_train.csv')
df_test = pd.read_csv('./Data/Q_2_test.csv')
X_train=df_train.loc[:,'V1':'V35']
X_test=df_test.loc[:,'V1':'V35']

y_train=df_train.loc[:,'V36']
y_test=df_test.loc[:,'V36']
X_train
# Out:
#        V1   V2  V3   V4  V5  V6   V7   V8   V9  V10  ...  V26  V27  V28  V29  \
# 0      31   81  54   46  51   6    7    0    0   42  ...    0    0   42   13
# 1     100  100  47   99  10  70    0   32   32    0  ...   32   32    0   88
# 2      33   93  84  100  90  78   46   59   94   47  ...   59   94   47  100
# 3      54   84  81  100  91  79   66   55  100   39  ...   55  100   39   86
# 4      16   65  29  100  59  83   38   41    0   12  ...   41    0   12    8
# ...   ...  ...  ..  ...  ..  ..  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 7689    0   75  31   72  67  84  100  100   94   82  ...  100   94   82   80
# 7690    0   25  35   48  64  75   97  100  100   88  ...  100  100   88   81
# 7691   20  100   7   84   0  50   65   50  100   67  ...   50  100   67   84
# 7692   38  100  16   68   0  36   51   30  100   34  ...   30  100   34   90
# 7693  100  100  72   81  55  55   45   27   48    0  ...   27   48    0   72
#
#       V30  V31  V32  V33  V34  V35
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
acc_matrix_test = []
acc_matrix_train = []
# Calculating error for K values between 1 and 40
for i in range(1, 30,2):
    #print(i)
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    pred_i = knn.predict(X_test)
    pred_i_tr= knn.predict(X_train)
    #print("****************************")
    sum_p_test=0
    sum_n_test=0
    sum_p_train=0
    sum_n_train=0
    for ind, y in enumerate(y_test):
        if(y==pred_i[ind]):
            sum_p_test=sum_p_test + 1
        else:
            sum_n_test=sum_n_test + 1
    for ind, y in enumerate(y_train):
        
        if(y==pred_i_tr[ind]):
            sum_p_train=sum_p_train + 1
        else:
            sum_n_train=sum_n_train + 1


    acc_matrix_test.append(sum_p_test/(sum_p_test+sum_n_test))
    acc_matrix_train.append(sum_p_train/(sum_p_train+sum_n_train))



plt.figure(figsize=(12, 6))
plt.plot(range(1, 30,2), acc_matrix_test, color='red', linestyle='dashed', marker='o',
         markerfacecolor='blue', markersize=10)
plt.plot(range(1, 30,2), acc_matrix_train, color='black', linestyle='dashed', marker='o',
         markerfacecolor='yellow', markersize=10)
plt.legend(['TEST_accuracy','TRAIN_accuracy'])
plt.title('TEST and TRAIN Accuracy by the K Value')

plt.xlabel('K Value')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
max(acc_matrix_test)
# Out:
# 0.9773980154355016

# %%
import numpy as np
from sklearn.model_selection import train_test_split
pca_7 = PCA(n_components = 7)
#principalComponents = pca.fit_transform(x)
pca_7_fit=pca_7.fit(df)
#ucq=pca_pred['V36'].unique()
pca_pred=pd.DataFrame(pca_7.fit_transform(df))
pca_pred=pd.concat([pca_pred,df['V36']],axis=1)
pca_pred

y = pca_pred.pop('V36')
X = pca_pred


X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.33, random_state=42)
X.index
# Out:
# RangeIndex(start=0, stop=10992, step=1)

# %%
from sklearn.neighbors import KNeighborsClassifier
acc_matrix_test = []
acc_matrix_train = []
# Calculating error for K values between 1 and 40
for i in range(1, 30,2):
    #print(i)
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    pred_i = knn.predict(X_test)
    pred_i_tr= knn.predict(X_train)
    #print("****************************")
    sum_p_test=0
    sum_n_test=0
    sum_p_train=0
    sum_n_train=0
    for ind, y in enumerate(y_test):
        if(y==pred_i[ind]):
            sum_p_test=sum_p_test + 1
        else:
            sum_n_test=sum_n_test + 1
    for ind, y in enumerate(y_train):
        
        if(y==pred_i_tr[ind]):
            sum_p_train=sum_p_train + 1
        else:
            sum_n_train=sum_n_train + 1


    acc_matrix_test.append(sum_p_test/(sum_p_test+sum_n_test))
    acc_matrix_train.append(sum_p_train/(sum_p_train+sum_n_train))



plt.figure(figsize=(12, 6))
plt.plot(range(1, 30,2), acc_matrix_test, color='red', linestyle='dashed', marker='o',
         markerfacecolor='blue', markersize=10)
plt.plot(range(1, 30,2), acc_matrix_train, color='black', linestyle='dashed', marker='o',
         markerfacecolor='yellow', markersize=10)
plt.legend(['TEST_accuracy','TRAIN_accuracy'])
plt.title('TEST and TRAIN Accuracy by the K Value')

plt.xlabel('K Value')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
max(acc_matrix_test)
# Out:
# 0.9773980154355016
